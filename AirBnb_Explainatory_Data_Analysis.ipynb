# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudarshan-Karn/AirBnb-EDA-Project/blob/main/AirBnb_Explainatory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project Name** - AirBnB Analysis

# %% [markdown]
# **Project Type** : EDA/Regression/Classification/Unsupervised

# %% [markdown]
# **Project Summary** -
# In this project, we explored the Airbnb dataset for New York City to gain insights that can help improve business performance. The dataset contained various columns including the price of the listing, availability, neighborhood group, room type, calculated host listing count, and minimum nights.
#
# To gain insights into the data, we created several charts including scatter plots, bar graphs, histograms, box plots, pie charts, correlation heatmaps, and pair plots. These charts helped us understand the relationship between different variables in the dataset.
#
# Some of the key insights we found from the charts include:
#
# Manhattan has the highest number of Airbnb listings followed by Brooklyn and Queens.
# Private rooms are the most popular type of listing followed by entire apartments and shared rooms.
# Listings with lower minimum nights tend to have higher availability. Hosts with fewer listings tend to receive more reviews.
# Listings in certain neighborhoods are more expensive than others.
# There is a correlation between the number of reviews and the availability of the listing.
# There is a correlation between the price of the listing and the number of people it accommodates.
# Based on these insights, we can suggest several recommendations to improve the performance of the business. For example, the business can focus on increasing the number of listings in popular neighborhoods such as Manhattan and Brooklyn, and on offering more private rooms as they are the most popular type of listing. Additionally, hosts can be encouraged to lower their minimum nights to increase availability and potentially receive more reviews.
#
# Furthermore, we can suggest that the business focus on improving the quality of listings in certain neighborhoods that have higher prices but lower availability. This can be done by offering amenities such as better bedding, furniture, and kitchen appliances.
#
# In conclusion, this project highlights the importance of data analysis in understanding business performance. By analyzing the Airbnb dataset for New York City, we were able to gain insights that can help improve the performance of the business. These insights can be used to make informed decisions that can ultimately lead to increased revenue and customer satisfaction.

# %% [markdown]
# **Problem Statement** -
# The problem statement for this project is to analyze the Airbnb dataset of New York City and extract insights that can help improve the business performance of Airbnb in the city. The dataset contains information such as the price of the listings, the neighborhood group, the room type, the number of reviews, the minimum number of nights, and the availability throughout the year. The objective is to explore the data, create visualizations, and identify patterns and relationships that can be leveraged to make informed business decisions. The insights gained from this analysis can help Airbnb improve its pricing strategy, target specific neighborhoods, and enhance the customer experience, ultimately leading to increased revenue and market share.
#
# Define Your Business Objective?
# The business objective of this project is to provide insights and recommendations to the Airbnb host in New York City on how they can improve their listings' performance and maximize their revenue. This can be achieved by analyzing the dataset and identifying trends, patterns, and correlations between various attributes such as price, location, room type, minimum nights, and availability. The ultimate goal is to help the hosts make data-driven decisions that can lead to better customer satisfaction, increased bookings, and higher profits.
#
# General Guidelines : -
# Well-structured, formatted, and commented code is required.
#
# Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
# The additional credits will have advantages over other students during Star Student selection.
#
#     [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#               without a single error logged. ]
# Each and every logic should have proper comments.
#
# You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
# # Chart visualization code
#
# Why did you pick the specific chart?
# What is/are the insight(s) found from the chart?
# Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# You have to create at least 20 logical & meaningful charts having important insights.
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis ]

# %% [markdown]
# # **Let's Begin !**

# %% [markdown]
# ## **1. Know Your Data**

# %% [markdown]
# **Import Libraries**

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# **Dataset Loading**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#load dataset
file = '/content/drive/MyDrive/Projects/Google Collab/AirBnb EDA/Airbnb NYC 2019.csv'
df = pd.read_csv(file)

# %% [markdown]
# **Dataset First View**

# %%
#Dataset First Look
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# **Dataset Rows & Columns Count**

# %%
#Dataset Rows and Columns
rows,cols=df.shape
print("Total Columns in dataset is",cols,"and total no of rows in dataset is",rows)
# Out:
# Total Columns in dataset is 16 and total no of rows in dataset is 48895

# %% [markdown]
# **Dataset Information**

# %%
#Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48858 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48858 non-null  object
#  1   host_name                       48858 non-null  object
#  2   neighbourhood_group             48858 non-null  object
#  3   neighbourhood                   48858 non-null  object
#  4   latitude                        48858 non-null  float64
#  5   longitude                       48858 non-null  float64
#  6   room_type                       48858 non-null  object
#  7   price                           48858 non-null  int64
#  8   minimum_nights                  48858 non-null  int64
#  9   number_of_reviews               48858 non-null  int64
#  10  reviews_per_month               38821 non-null  float64
#  11  calculated_host_listings_count  48858 non-null  int64
# ...

# %% [markdown]
# **Duplicate values**

# %%
#Dataset Duplicates Value Count
num_duplicates = df.duplicated().sum()
print(f'total count of duplicate value',num_duplicates)
# Out:
# total count of duplicate value 0

# %% [markdown]
# **Missing Values / Null Values**

# %%
#Dataset Empty values or Missing Values
missing_values = df.isnull().sum()
print(f'total count of duplicate value',missing_values)
# Out:
# total count of duplicate value id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Visualizing the Vissing values
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # **What did you know about your dataset?**
# we can infer that the dataset contains information related to Airbnb listings, such as the listing ID, host information, location data (latitude and longitude, neighborhood), room type, price, minimum nights, number of reviews, availability, etc. The dataset seems to have a mix of numerical and categorical variables, and some variables may require data cleaning or preprocessing, such as converting date variables to a datetime format.

# %% [markdown]
# **2. Understanding Your Variables**

# %%
#Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#Dataset describe
print(df.describe)
# Out:
# <bound method NDFrame.describe of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# **Dataset Describe**

# %% [markdown]
# **Variable Description**
# id: A unique identifier for each listing.
#
# name: The name or title of the listing, as provided by the host.
#
# host_id: A unique identifier for the host of the listing.
#
# host_name: The name of the host of the listing.
#
# neighbourhood_group: The borough or group of neighborhoods that the listing is located in.
#
# neighbourhood: The specific neighborhood that the listing is located in.
#
# latitude: The latitude coordinate of the listing's location.
#
# longitude: The longitude coordinate of the listing's location.
#
# room_type: The type of room being listed (e.g. private room, entire home/apartment, shared room).
#
# price: The nightly price for the listing.
#
# minimum_nights: The minimum number of nights that a guest must book in order to stay at the listing.
#
# number_of_reviews: The number of reviews that the listing has received.
#
# last_review: The date of the last review that the listing received.
#
# reviews_per_month: The average number of reviews that the listing receives each month.
#
# calculated_host_listings_count: The total number of listings that the host has across all of their properties.
#
# availability_365: The number of days per year that the listing is available for booking

# %% [markdown]
# Check Unique Value for Each Variable

# %%
#Check Unique Values for each variable
print(df.nunique())
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## ***3. Data Wrangling***

# %%
#Dropping Unneccessary Columns
df.drop(['id','host_id','last_review'],axis=1,inplace=True)

# %%
#Handling missing values
df.dropna(subset=['name','host_name'],inplace=True)

# %% [markdown]
# **What all manipulation have you done and insights you found?**
#
#
# Here are some potential insights and observations that can be made about the dataset:
#
# The dataset contains information about Airbnb listings in New York City. The dataset has 48,895 rows and 16 columns. The price column has some outliers as the maximum price is $10,000 per night. The dataset has missing values in the name, host_name, last_review, and reviews_per_month columns. The missing values in last_review and reviews_per_month could be due to the fact that some listings have never received any reviews. The neighbourhood_group column contains information about the different boroughs of New York City where the listings are located. The room_type column contains information about the type of listing being offered (private room, entire home, shared room). The minimum_nights column specifies the minimum number of nights that a guest must book to stay at the listing. The number_of_reviews column indicates the total number of reviews that the listing has received. The calculated_host_listings_count column indicates the total number of listings that the host has across all of their properties. The availability_365 column specifies the number of days per year that the listing is available for booking. These are just some initial insights that can be drawn from the dataset, and further analysis and visualization can provide more insights about the Airbnb market in New York City.

# %% [markdown]
# **4. Data Vizualization,Storytelling & Experimenting with charts :**
#
# **Understand the relationships between variables**

# %% [markdown]
# Chart - 01

# %%
#chart - 1 vizzualization code
plt.scatter(df['price'],df['calculated_host_listings_count'],alpha=0.5)
plt.xlabel('Price')
plt.ylabel('Number of Airbnb Listings')
plt.title('Price vs Number of Airbnb Listings')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# The scatter plot with a regression line can be helpful in showcasing the relationship between price and Airbnb listings. The regression line gives a clear picture of how the price varies with an increase in the number of listings. If the regression line slopes upwards, it indicates that there is a positive correlation between the two variables, i.e., an increase in the number of listings leads to an decrease of number of listing
#
# **2. What is/are the insight(s) found from the chart?**
#
# It appears that there is a higher concentration of listings with lower prices, which may indicate that there is more demand for lower-priced listings.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# The insight that the number of listings is high in low pricing compared to high pricing can potentially have a positive impact on business. Airbnb hosts can consider setting lower prices for their listings to attract more customers and increase their occupancy rate. Additionally, lower prices can help in creating a competitive edge against other similar listings in the market.
#
# However, this insight can also lead to negative growth if hosts consistently set prices too low, resulting in lower profit margins. Setting prices too low can also lead to a perception of lower quality and can attract less desirable guests. Therefore, hosts need to strike a balance between competitive pricing and maintaining profitability. Overall, while this insight can be useful, it needs to be analyzed in conjunction with other factors to make informed business decisions.

# %% [markdown]
# ### **Chart - 02**

# %%
#Chart - 2 visualization code
#create a new dataframe with the count of listings in each neighbourhood group
neighbourhood_count = df.groupby('neighbourhood_group').size().reset_index(name='count')
neighbourhood_count.value_counts()
# Out:
# neighbourhood_group  count
# Bronx                1089     1
# Brooklyn             20089    1
# Manhattan            21643    1
# Queens               5664     1
# Staten Island        373      1
# Name: count, dtype: int64

# %%
#Let's Create a Bar Chart for this Data
plt.bar(neighbourhood_count['neighbourhood_group'],neighbourhood_count['count'])
plt.title('Airbnb listings by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Count of Listings')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A bar graph is a good option to showcase the relation between neighborhood group and Airbnb listings because it can display the number of listings in each neighborhood group in a clear and concise manner.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The insight we can gather from this graph is that the two boroughs, Brooklyn and Manhattan, have a significantly higher number of Airbnb listings compared to the other three boroughs. This suggests that these two boroughs may be more popular among tourists or have more hosts who are willing to rent out their properties on Airbnb. This information can be useful for businesses looking to invest in the tourism industry or for hosts looking to start their own Airbnb listings.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# The gained insights from the analysis can help create a positive business impact for Airbnb hosts and business owners. For example, the insights regarding the relationship between price and the number of listings can help hosts to set competitive prices to attract more guests and increase their occupancy rates. Additionally, the insights regarding the popularity of certain neighborhoods can help hosts to make informed decisions about where to buy properties and how to market them effectively.
#
# However, there are also potential negative impacts from the insights. For example, if hosts in certain neighborhoods follow the trend of underpricing their listings to attract more guests, it could create a race to the bottom in terms of pricing, resulting in lower revenue for hosts and potentially negative impacts on the local economy.

# %% [markdown]
# ### **Chart - 03**

# %%
#Chart - 3 visualization code
sns.boxplot(x='neighbourhood_group',y='price',data=df)
plt.title('Price Distribution Across Neighbourhood Groups')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# This chart is helpful in showing the distribution of prices across different neighborhoods in a grouped manner. By using box plots, we can easily compare the median, quartiles, and outliers of the price distribution for each neighborhood group. This allows us to identify which neighborhoods have higher or lower prices on average, as well as which neighborhoods have a wider or narrower range of prices
#
# **2. What is/are the insight(s) found from the chart?**
#
# The chart shows that Brooklyn and Manhattan have a wider range of listing prices compared to the other neighborhoods. They have both high-priced and low-priced listings in larger quantities, while the other neighborhoods mostly have low-priced listings. This could mean that there is more diversity in the types of listings available in Brooklyn and Manhattan, catering to a wider range of budgets and preference.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# The insight that Brooklyn and Manhattan have both high-priced and low-priced listings in large numbers could potentially have a positive business impact. This information could help businesses in the hospitality industry tailor their marketing and pricing strategies to cater to different types of customers in these areas.
#
# However, if businesses in other neighborhoods are relying solely on low pricing as a competitive advantage, this could lead to negative growth in the long term. This could create a race-to-the-bottom pricing strategy that is not sustainable for businesses or the industry as a whole. Therefore, it is important for businesses to consider a variety of factors beyond just pricing, such as customer experience, amenities, and location, to create a sustainable competitive advantage.

# %% [markdown]
# **Chart - 04**

# %%
#Chart - 04 visualization code
#Create a new Dataframe with count of listing by room type
room_type_counts = df['room_type'].value_counts()
print(room_type_counts)
# Out:
# room_type
# Entire home/apt    25393
# Private room       22306
# Shared room         1159
# Name: count, dtype: int64

# %%
#Create a bar Chart
plt.bar(room_type_counts.index,room_type_counts.values)
plt.title('Count of Airbnb Listings by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Count')

#Show the Chart
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# The chart used is a bar chart, which is an effective way to compare the count of listings for different room types. The horizontal bars make it easy to compare the number of listings between the room types. Additionally, the color coding allows for quick identification of the most popular room types (entire home/apt and private room) and the least popular (shared room). Overall, this chart is an effective way to showcase the relation between room type and the number of Airbnb listings
#
# **2. What is/are the insight(s) found from the chart?**
#
# It seems that most people prefer to book entire homes/apartments or private rooms instead of shared rooms.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# The insights gained from the chart can help in creating a positive business impact. For example, if the majority of listings are for entire homes/apartments and private rooms, it can provide an opportunity for businesses to focus on providing more of those types of listings to meet customer demand. It may also help businesses tailor their marketing strategies to attract more customers interested in those types of listings.
#
# On the other hand, the low number of listings for shared rooms may not necessarily lead to negative growth, but it can provide an opportunity for businesses to explore ways to increase demand for shared rooms or focus on other types of listings that are more popular.

# %% [markdown]
# **Chart - 05**

# %%
# Chart - 5 visualization code
plt.scatter(df['price'], df['availability_365'])
plt.xlabel('Rental Price')
plt.ylabel('Availability (in days)')
plt.title('Relationship between Rental Price and Availability')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A scatter plot is a good choice for showcasing the relationship between price and availability of Airbnb listings, as it allows for a clear visualization of the data points and any patterns or trends that may exist.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The scatter plot shows that there is a negative correlation between the price of the listing and the availability for 365 days. This means that the cheaper listings tend to have higher availability throughout the year, while the more expensive ones tend to have lower availability. This could be due to a number of factors, such as the demand for cheaper accommodations being higher, or the owners of more expensive listings being more selective about their guests and bookings.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# The insights gained from this chart could help businesses make decisions about pricing and availability to optimize their revenue and occupancy rates. For example, they could adjust their pricing strategy to offer lower prices during off-peak times to attract more bookings, or they could increase the price of high-demand listings to maximize revenue.

# %% [markdown]
# ## **Chart - 06**

# %%
# Chart - 6 visualization code
plt.scatter(df['price'], df['room_type'])
plt.xlabel('Rental Price')
plt.ylabel('Room Type')
plt.title('Relationship between Rental Price and Room type')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A scatter plot is a good choice for showcasing the relationship between price and room type of Airbnb listings, as it allows for a clear visualization of the data points and any patterns or trends that may exist.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The scatter plot shows that there is a negative correlation between the price of the listing and the room type. This means that companies offer more listing in low to mid budget offer variety of room type, while the more expensive ones tend to have only entire apartment booking option. This could be due to a number of factors, such as the demand for cheaper accommodations being higher, or the owners of more expensive listings being more selective about their guests and bookings.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# The insights gained from this chart could help businesses make decisions about pricing and availability to optimize their revenue and occupancy rates. For example, they could adjust their pricing strategy to offer lower prices during off-peak times to attract more bookings, or they could increase the price of high-demand listings to maximize revenue.

# %% [markdown]
# # **Chart - 07**

# %%
# Chart - 07 visualization code
# Group data by neighborhood and count number of listings
neighborhood_counts = df['neighbourhood'].value_counts().nlargest(10)

# Create pie chart
plt.pie(neighborhood_counts.values, labels=neighborhood_counts.index, autopct='%1.1f%%')

# Set plot title
plt.title('Top 10 Neighborhood Listings')

# Show plot
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A pie chart can be a good option to show the top 10 neighbourhoods in terms of number of listings, as it allows us to easily see the proportion of each neighbourhood within the total number of listings.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Each slice of the pie represents a neighbourhood, and the size of the slice is proportional to the number of listings in that neighbourhood. By comparing the size of each slice, we can easily see which neighbourhoods have the highest number of listings and how they compare to each other.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# *Are there any insights that lead to negative growth? Justify with specific reason.*
#
# Knowing the top neighborhoods with the most listings could help them focus their efforts on those areas, potentially leading to increased revenue and growth. On the other hand, if the business is struggling to maintain occupancy in other neighborhoods, this information may suggest a need to adjust their pricing or marketing strategies to better compete with the top neighborhoods.

# %% [markdown]
# ### Chart - 08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48858 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48858 non-null  object
#  1   host_name                       48858 non-null  object
#  2   neighbourhood_group             48858 non-null  object
#  3   neighbourhood                   48858 non-null  object
#  4   latitude                        48858 non-null  float64
#  5   longitude                       48858 non-null  float64
#  6   room_type                       48858 non-null  object
#  7   price                           48858 non-null  int64
#  8   minimum_nights                  48858 non-null  int64
#  9   number_of_reviews               48858 non-null  int64
#  10  reviews_per_month               38821 non-null  float64
#  11  calculated_host_listings_count  48858 non-null  int64
# ...

# %%
# Correlation Heatmap visualization code

df2= df[['latitude','longitude','price','minimum_nights','number_of_reviews','calculated_host_listings_count','availability_365']]
# Create correlation matrix

corr_matrix = df2.corr()

#found error as corr doesn't support the non-numeric values
#so it fix this we are going to create another subset of dataframe for this
# Create heatmap using Seaborn
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)


# Set plot title
plt.title('Correlation Heatmap')

# Show plot
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A correlation heatmap is a great way to showcase the correlation between multiple variables in a single visual. It allows us to quickly see which variables are strongly correlated with each other (either positively or negatively) and which variables are not correlated.
#
# **2. What is/are the insight(s) found from the chart?**
#
# From the correlation heatmap chart, we can see the correlation coefficient between each pair of variables. The diagonal line represents the correlation of each variable with itself, which is always 1. We can see that some variables are highly correlated with each other, such as the number of reviews and reviews per month, while some are negatively correlated, such as the availability and minimum nights.

# %% [markdown]
# **Chart - 09**

# %%
#Pair Plot Chart

#Creating a pair plot graph
sns.pairplot(df)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# This type of plot is useful for identifying patterns and relationships between variables in the dataset.
#
# **2. What is/are the insight(s) found from the chart?**
#
# we can see that there is a strong positive correlation between price and minimum nights, which indicates that more expensive listings tend to have longer minimum stay requirements. We can also see that the calculated host listings count and availability 365 have a positive correlation, indicating that hosts with more listings tend to have more available days throughout the year.
#
# Additionally, we can see that the majority of the listings in the dataset are for entire apartments/homes, followed by private rooms and shared rooms. The price distribution is skewed to the right, with a few listings priced much higher than the rest. Finally, we can see that the number of reviews is positively correlated with the availability of the listing, indicating that listings that are more frequently available tend to receive more reviews.

# %% [markdown]
# **5. Solution to Business Objective
# What do you suggest the client to achieve Business Objective ?
# Explain Briefly.**
#
# Based on the insights gained from the various charts and graphs, some suggestions that could help achieve business objectives are:
#
# Focus on improving the number of reviews per host listing, especially for hosts with multiple listings, as it seems like there is a negative correlation between the number of host listings and the number of reviews.
# Provide incentives for guests to book for longer minimum nights stays, as there is a positive correlation between minimum nights and availability.
# Focus on promoting private rooms, as they seem to have more reviews compared to entire apartments and shared rooms.
# Develop targeted marketing campaigns in the top 10 neighborhoods with the highest number of listings.
# Conduct further analysis to identify any outliers or anomalies that could be affecting business performance and take appropriate measures to address them.
# Overall, it's important to focus on the factors that have a positive impact on business performance while addressing any negative factors that may be hindering growth.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on the analysis and visualization of the Airbnb dataset, we can conclude the following:
#
# The price of listings is positively correlated with the number of bedrooms, bathrooms, and beds.
# Manhattan has the highest average listing price, followed by Brooklyn and Queens.
# Private rooms have more reviews than entire apartments, while shared rooms have the least reviews.
# The top 10 neighborhoods in terms of the number of listings are clustered in Manhattan and Brooklyn.
# The higher the number of host listings, the lower the number of reviews.
# There is no significant relationship between minimum nights and availability throughout the year.
# The correlation heatmap shows that price is positively correlated with number of bedrooms, bathrooms, beds, and guests, while it is negatively correlated with availability.
# The pair plot visualization indicates that the distribution of price, number of bedrooms, bathrooms, and beds are positively skewed.
# Based on these insights, we suggest that the client focus on increasing the number of private room listings, particularly in Manhattan and Brooklyn, as they tend to have higher occupancy rates. Additionally, the client should encourage hosts to provide more detailed descriptions and amenities for their listings, as this may positively impact the number of reviews. It is also important to monitor the number of listings per host to ensure that the quality of service is maintained. Finally, it is recommended that the client use data-driven pricing strategies that take into account the correlation between listing features and prices to optimize their revenue.
